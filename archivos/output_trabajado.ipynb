# %% [markdown]
# TRABAJO AL ARCHIVO OUTPUT

# %% [markdown]
# Importamos las librerias a utilizar

# %%
import pandas as pd
import json

# %% [markdown]
# Abrimos el archivo que esta en Formato JSON

# %%
# Ruta al dataset australian_user_reviews
output_ruta = 'D:\escritorio\STEAM\Json\output_steam_games.json'

# Se lee de cada línea del dataset
filas_games = []
with open(output_ruta) as f:
    for line in f.readlines():
        data = json.loads(line)
        filas_games.append(data)

# Se convierte en dataframe
output = pd.DataFrame(filas_games)
output
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# ...

# %% [markdown]
# Consultamos cuantos valores nulos posee nuestro archivo y lo eliminamos

# %%
# Cuenta la cantidad de nulos por columna
print(output.isnull().sum())
print("Total de valores nulos:",output.isnull().sum().sum())
# Out:
# publisher       96362
# genres          91593
# app_name        88312
# title           90360
# url             88310
# release_date    90377
# tags            88473
# reviews_url     88312
# specs           88980
# price           89687
# early_access    88310
# id              88312
# developer       91609
# dtype: int64
# Total de valores nulos: 1168997

# %%
output.dropna(how='all', inplace=True)

# %% [markdown]
# Controlamos cuantos valores nulos hay por columna

# %%
print(output.isnull().sum())
# Out:
# publisher       8052
# genres          3283
# app_name           2
# title           2050
# url                0
# release_date    2067
# tags             163
# reviews_url        2
# specs            670
# price           1377
# early_access       0
# id                 2
# developer       3299
# dtype: int64

# %% [markdown]
# Consultamos cuanto valores duplicados con de la columna id

# %%
output['id'].duplicated().sum()
# Out:
# 2

# %%
# Cuento las veces que aparece cada id
counts_id = output['id'].value_counts()
# Imprime los que aparecen mas de 1 vez
print(counts_id[counts_id>1])
# Out:
# id
# 612880    2
# Name: count, dtype: int64

# %%
# Identificar valores duplicados en la columna 'ID'
duplicados = output[output.duplicated(subset=['id'], keep=False)]
# Obtener las filas completas correspondientes a los valores duplicados
filas_duplicadas = output[output['id'].isin(duplicados['id'])]
filas_duplicadas
# Out:
#                                                 publisher  \
# 88384                                                 NaN
# 102204                                 Bethesda Softworks
# 102883                                 Bethesda Softworks
# 119271  Warner Bros. Interactive Entertainment, Feral ...
#
#                      genres                                        app_name  \
# 88384                   NaN                                             NaN
# 102204             [Action]                Wolfenstein II: The New Colossus
# 102883             [Action]                Wolfenstein II: The New Colossus
# 119271  [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
#
#                                                  title  \
# 88384                                              NaN
# 102204                Wolfenstein II: The New Colossus
# 102883                Wolfenstein II: The New Colossus
# 119271  Batman: Arkham City - Game of the Year Edition
#
# ...

# %%
# Eliminar los duplicados manteniendo solo una instancia de cada uno
output_sin_duplicados = output.drop_duplicates(subset=['id'], keep='first')
output_sin_duplicados
# Out:
#                publisher                                             genres  \
# 88310          Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311   Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312       Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313               彼岸领域                        [Action, Adventure, Casual]
# 88314                NaN                                                NaN
# ...                  ...                                                ...
# 120440   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 120441            Sacada                          [Casual, Indie, Strategy]
# 120442      Laush Studio                        [Indie, Racing, Simulation]
# 120443          SIXNAILS                                    [Casual, Indie]
# 120444               NaN                                                NaN
#
# ...

# %% [markdown]
# Normalizamos los datos de la columna id

# %%
output['id'] = output['id'].astype(str)

# Remplazo los '.0' por '' (vacio)
output['id'] = output['id'].str.replace('.0','')
# Elimino lo vacio
output['id'] = output['id'].str.strip()

# %% [markdown]
# Cambiamos los valores de la fecha a datatime

# %%
output['release_date']= pd.to_datetime(output['release_date'], errors='coerce')

# %%
# Extraigo el año lo almaceno como string en 'release_year' y relleno con 'sin dato' los nulos
output['release_year'] = output['release_date'].dt.year.fillna('sin dato').astype(str)

# Esto va porque al pasar el año a string aparece con .0 al final (ej: 2015.0)
output['release_year'] = output['release_year'].str.replace('.0','')
#Elimina los espacios en blanco 
output['release_year'] = output['release_year'].str.strip()

# %%
#Elimino la columna 'release_date'
output.drop(['release_date'],axis=1,inplace=True)

# %% [markdown]
# Cambiamos los datos de la columna price

# %%
precios = output['price'].unique()
precios
# Out:
# array([4.99, 'Free To Play', 'Free to Play', 0.99, 2.99, 3.99, 9.99,
#        18.99, 29.99, nan, 'Free', 10.99, 1.59, 14.99, 1.99, 59.99, 8.99,
#        6.99, 7.99, 39.99, 19.99, 7.49, 12.99, 5.99, 2.49, 15.99, 1.25,
#        24.99, 17.99, 61.99, 3.49, 11.99, 13.99, 'Free Demo',
#        'Play for Free!', 34.99, 74.76, 1.49, 32.99, 99.99, 14.95, 69.99,
#        16.99, 79.99, 49.99, 5.0, 44.99, 13.98, 29.96, 119.99, 109.99,
#        149.99, 771.71, 'Install Now', 21.99, 89.99,
#        'Play WARMACHINE: Tactics Demo', 0.98, 139.92, 4.29, 64.99,
#        'Free Mod', 54.99, 74.99, 'Install Theme', 0.89, 'Third-party',
#        0.5, 'Play Now', 299.99, 1.29, 3.0, 15.0, 5.49, 23.99, 49.0, 20.99,
#        10.93, 1.39, 'Free HITMAN™ Holiday Pack', 36.99, 4.49, 2.0, 4.0,
#        9.0, 234.99, 1.95, 1.5, 199.0, 189.0, 6.66, 27.99, 10.49, 129.99,
#        179.0, 26.99, 399.99, 31.99, 399.0, 20.0, 40.0, 3.33, 199.99,
#        22.99, 320.0, 38.85, 71.7, 59.95, 995.0, 27.49, 3.39, 6.0, 19.95,
# ...

# %%
# Define una función para convertir valores a punto flotante
def reemplaza_a_flotante(valor):
    try:
        # Intenta convertir el valor a punto flotante
        return float(valor)
    except (ValueError, TypeError):
        # Si no se puede convertir, devuelve NaN
        return float('nan')

# Aplica la función a la columna 'price'
output['price'] = output['price'].apply(reemplaza_a_flotante)

# Verifica el tipo de datos de la columna 'price'
print(output['price'].dtype)
# Out:
# float64

# %%
output['price'].fillna(0.00, inplace=True)

# %% [markdown]
# Vemos como nos quedo el dataframe

# %%
output.head(3)
# Out:
#               publisher                                             genres  \
# 88310         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
#
#                       app_name                    title  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty
# 88311                Ironbound                Ironbound
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians
#
#                                                      url  \
# 88310  http://store.steampowered.com/app/761140/Lost_...
# 88311  http://store.steampowered.com/app/643980/Ironb...
# 88312  http://store.steampowered.com/app/670290/Real_...
#
#                                                     tags  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...
# ...

# %% [markdown]
# Transformacion de la columna genre

# %%
# Funcion para obtener  
def clean_genres(genres):
    if isinstance(genres, list):# Si 'genres' es una lista. Devuelve el primer elemento
        return genres[0]
    elif isinstance(genres, str): # Si 'genres' es un string. Devuelve ese valor
        return genres
    else:
        return 'Pending classification' 

# Se aplica la funcion a la columna 'genres'  
output['genres'] = output['genres'].apply(clean_genres)

# %%
output['genres'].value_counts()
# Out:
# genres
# Action                       11318
# Casual                        4340
# Adventure                     4328
# Indie                         3299
# Pending classification        3283
# Simulation                    1852
# Strategy                      1143
# RPG                            685
# Free to Play                   523
# Racing                         454
# Design &amp; Illustration      327
# Animation &amp; Modeling       179
# Utilities                       93
# Audio Production                84
# Sports                          63
# Massively Multiplayer           49
# Education                       46
# Video Production                21
# Software Training               21
# Web Publishing                   8
# Photo Editing                    8
# Accounting                       7
# Early Access                     4
# Name: count, dtype: int64

# %% [markdown]
# Volvemos a ver cuanto nulos hay por columnas

# %%
# Cuento la cantidad de nulos que quedaron por columna
print(output.isnull().sum())
# Out:
# publisher       8052
# genres             0
# app_name           2
# title           2050
# url                0
# tags             163
# reviews_url        2
# specs            670
# price              0
# early_access       0
# id                 0
# developer       3299
# release_year       0
# dtype: int64

# %% [markdown]
# Eliminamos las columnas que no vamos a necesitar para llevar adelante el proyecto

# %%
output_games = output.drop(['tags', 'specs', 'url', 'reviews_url', 'publisher', 'title', 'early_access'], axis=1)
output_games.columns
# Out:
# Index(['genres', 'app_name', 'price', 'id', 'developer', 'release_year'], dtype='object')

# %% [markdown]
# Eliminamos los valores nulos de la columna developer

# %%
# Eliminar filas con valores nulos en la columna 'developer'
output_games = output_games.dropna(subset=['developer'])

# %% [markdown]
# Se verifican el tipo de dato y si quedan nulos.

# %%
# Obtener la cantidad de valores nulos por columna
valores_nulos_por_columna = output_games.isnull().sum()

# Calcular el porcentaje de valores nulos por columna
total_valores_por_columna = len(output_games)
porcentaje_valores_nulos_por_columna = (valores_nulos_por_columna / total_valores_por_columna) * 100

# Crear un DataFrame con el formato deseado
resultado_df = pd.DataFrame({
    'nombre_campo': valores_nulos_por_columna.index,
    'no_nulos_%': 100 - porcentaje_valores_nulos_por_columna,
    'nulos_%': porcentaje_valores_nulos_por_columna,
    'nulos': valores_nulos_por_columna
})

# Mostrar el resultado
print(resultado_df)
# Out:
#               nombre_campo  no_nulos_%  nulos_%  nulos
# genres              genres       100.0      0.0      0
# app_name          app_name       100.0      0.0      0
# price                price       100.0      0.0      0
# id                      id       100.0      0.0      0
# developer        developer       100.0      0.0      0
# release_year  release_year       100.0      0.0      0

# %% [markdown]
# Vemos cuantas filas tenemos y procedemos a eliminar unas cuantas filas. Esto lo realizo porque el espacio para renderizar es limitado

# %%
num_filas = output_games.shape[0]
print("Número de filas en el DataFrame:", num_filas)
# Out:
# Número de filas en el DataFrame: 28836

# %%
output_games = output_games.iloc[:18000]
output_games
# Out:
#               genres                                           app_name  \
# 88310         Action                                Lost Summoner Kitty
# 88311   Free to Play                                          Ironbound
# 88312         Casual                            Real Pool 3D - Poolians
# 88313         Action                                            弹炸人2222
# 88315         Action                              Battle Royale Trainer
# ...              ...                                                ...
# 108822         Indie  Fantasy Grounds - Mini-Dungeon #012: Nekh-ta-N...
# 108823         Indie                    Fantasy Grounds - Kingdoms (5E)
# 108824         Indie  Fantasy Grounds - Mini-Dungeon #013: The Case ...
# 108825     Adventure             A New Beginning - Final Cut Soundtrack
# 108826     Adventure                                 Memoria Soundtrack
#
#         price      id               developer release_year
# ...

# %% [markdown]
# Por ultimo guardamos todo en un formato csv

# %% [markdown]
# GUARDAMOS EL ARCHIVO EN FORMATO CSV

# %%
output_games.to_parquet('D:/escritorio/STEAM/parquet/output_game.parquet')
